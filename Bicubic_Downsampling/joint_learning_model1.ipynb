# %%
import os
os.environ['OMP_NUM_THREADS']='2'
os.environ['LD_LIBRARY_PATH']=''
os.environ['CUDA_LAUNCH_BLOCKING']='1'

# %%
# %cd /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR
# Out:
# /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR

# %%
from data_generation import *
from scipy.linalg import sqrtm
from downscaling import *
from utils import *
import random

# %%
# %cd Bicubic_Downsampling/
# Out:
# /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR/Bicubic_Downsampling

# %% [markdown]
# ## Langevin & Training Downscale Network

# %% [markdown]
# ### Upscale By 4

# %%
N_low = 30
N_high = 120
scale = 4

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
A_high = create_A(N_high)
A_low = create_A(N_low)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for prior variance
prior_sigma = 0.002
ll_sigma = 0.002

# %%
G = np.eye(N_high**2) * prior_sigma**2
G_inverse = np.eye(N_high**2) * (1/prior_sigma**2)

# Turn matrices to tensors
G = torch.tensor(G).to(torch.float32).to(device)
G_inverse = torch.tensor(G_inverse).to(torch.float32).to(device)
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)

# Store sparse matrices as sparse tensor
A_high = A_high.to_sparse()
G = G.to_sparse()
G_inverse = G_inverse.to_sparse()
operator = torch.spmm(A_high.T,G_inverse).to(device)

# %%
dataset = DataFromH5File4("/home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR/data/30_120_low_forcing.h5")

trainset = random.sample(range(0, 128), 100)
testset = [i for i in range(0,128) if i not in trainset]

# %%
def sample_data():
    coefficient = random.sample(trainset,1)[0]
    forcing = dataset[coefficient][0]
    lr = dataset[coefficient][1]
    
    return forcing, lr


def sample_p_0():
    # Randomly sampling for initialisation of the Langevin dynamics
    # prior = torch.randn(*[batch_size,1,20,20]).to(device)
    
    # Set the u_low_mean to the initialisation of the Langevin dynamics
    posterior_initial = torch.randn([N_high,N_high]).to(torch.float32)
    posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
    
    return posterior_initial

    
def ula_posterior_preconditioner(z, b_high, x, G):
    """
    Langevin dynamics with preconditioner
    """
    z = z.clone().detach().requires_grad_(True)
    for i in range(K):
        # Grad log-likelihood
        x_hat = G(z.reshape(1,N_high,N_high)).reshape(N_low,N_low)
        log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
        grad_ll = torch.autograd.grad(log_likelihood, z)[0]

        # Grad prior
        difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
        # log_prior = - 0.5 * difference.T @ G_inverse @ difference
        # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
        grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
        
        # Random noise term
        W = torch.randn(*[N_high,N_high]).to(device)
        # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
        
        z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
        # chains_evolution.append(z.cpu().data.numpy())   
           
    return z.detach()

# %%
# Train with sampled data
epoch_num = 1000
lr = 0.003
gamma = 0.5
step_size = 30
minimum_loss = float('inf')
loss_track = []

K = 10000
s = 0.0004

G = DownScale()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=step_size, gamma=gamma)

# Logger info
dir_name = f'models/model1/30_120/lr{lr}_gamma{gamma}_stepsize{step_size}_K{K}_llsigma_{ll_sigma}_psigma{prior_sigma}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    b_high, low_res = sample_data()
    b_high = torch.tensor(b_high).to(torch.float32).to(device)
    low_res = torch.tensor(low_res).to(torch.float32).to(device)
    
    posterior_initial = sample_p_0()
    posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)

    optG.zero_grad()
    
    out = G(posterior_final.reshape(1,N_high,N_high)).reshape(N_low,N_low)
    loss = mse(out,low_res)
    
    loss.backward()
    optG.step()
    
    if loss < minimum_loss:
        save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
        minimum_loss = loss
            
    if epoch%100 == 0:
        save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
    
    save_model(dir_name, epoch, 'current_epoch', r_scheduleG, G, optG)
    loss_track.append(loss.cpu().data.numpy())
    np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
    
    print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()
# Out:
# 2024-06-05 10:17:10,405 : Training for 1000 epoches and learning rate is 0.003
# /tmp/ipykernel_31514/4059471450.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
# Epoch: 1 Loss: tensor(19.9299, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 2 Loss: tensor(4.8955, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 3 Loss: tensor(3.5308, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 4 Loss: tensor(2.2705, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 5 Loss: tensor(2.8706, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 6 Loss: tensor(1.6102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 7 Loss: tensor(1.6186, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 8 Loss: tensor(0.3768, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 9 Loss: tensor(0.8783, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 10 Loss: tensor(0.6366, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 11 Loss: tensor(0.2234, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 12 Loss: tensor(0.5386, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 13 Loss: tensor(0.1836, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 14 Loss: tensor(0.2164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 15 Loss: tensor(0.5467, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 16 Loss: tensor(0.3777, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 17 Loss: tensor(0.1188, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 18 Loss: tensor(0.0933, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 19 Loss: tensor(0.0942, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 20 Loss: tensor(0.0519, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 21 Loss: tensor(1.5303, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 22 Loss: tensor(0.1008, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 23 Loss: tensor(0.1527, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 24 Loss: tensor(0.2083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 25 Loss: tensor(0.1192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 26 Loss: tensor(0.0386, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 27 Loss: tensor(0.0904, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 28 Loss: tensor(0.0560, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 29 Loss: tensor(0.0730, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 30 Loss: tensor(0.0572, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 31 Loss: tensor(0.0313, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 32 Loss: tensor(0.1043, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 33 Loss: tensor(0.0356, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 34 Loss: tensor(0.0594, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 35 Loss: tensor(0.0532, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 36 Loss: tensor(0.0452, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 37 Loss: tensor(0.0400, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 38 Loss: tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 39 Loss: tensor(0.0331, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 40 Loss: tensor(0.3030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 41 Loss: tensor(0.0364, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 42 Loss: tensor(0.0436, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 43 Loss: tensor(0.0320, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 44 Loss: tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 45 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 46 Loss: tensor(0.0404, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 47 Loss: tensor(0.0462, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 48 Loss: tensor(0.0245, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 49 Loss: tensor(0.0400, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 50 Loss: tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 51 Loss: tensor(0.0313, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 52 Loss: tensor(0.0365, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 53 Loss: tensor(0.0416, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 54 Loss: tensor(0.0402, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 55 Loss: tensor(0.0306, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 56 Loss: tensor(0.0361, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 57 Loss: tensor(0.0259, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 58 Loss: tensor(0.0267, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 59 Loss: tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 60 Loss: tensor(0.0629, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 61 Loss: tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 62 Loss: tensor(0.0735, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 63 Loss: tensor(0.0359, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 64 Loss: tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 65 Loss: tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 66 Loss: tensor(0.0507, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 67 Loss: tensor(0.0544, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 68 Loss: tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 69 Loss: tensor(0.0595, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 70 Loss: tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 71 Loss: tensor(0.0429, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 72 Loss: tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 73 Loss: tensor(0.0346, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 74 Loss: tensor(0.0511, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 75 Loss: tensor(0.0477, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 76 Loss: tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 77 Loss: tensor(0.0434, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 78 Loss: tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 79 Loss: tensor(0.0370, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 80 Loss: tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 81 Loss: tensor(0.0409, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 82 Loss: tensor(0.0378, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 83 Loss: tensor(0.0319, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 84 Loss: tensor(0.0323, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 85 Loss: tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 86 Loss: tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 87 Loss: tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 88 Loss: tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 89 Loss: tensor(0.0175, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 90 Loss: tensor(0.0375, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 91 Loss: tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 92 Loss: tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 93 Loss: tensor(0.0427, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 94 Loss: tensor(0.0413, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 95 Loss: tensor(0.0542, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 96 Loss: tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 97 Loss: tensor(0.0527, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 98 Loss: tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 99 Loss: tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 100 Loss: tensor(0.0372, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 101 Loss: tensor(0.0263, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 102 Loss: tensor(0.0332, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 103 Loss: tensor(0.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 104 Loss: tensor(0.0473, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 105 Loss: tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 106 Loss: tensor(0.0393, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 107 Loss: tensor(0.0681, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 108 Loss: tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 109 Loss: tensor(0.0345, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 110 Loss: tensor(0.0339, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 111 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 112 Loss: tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 113 Loss: tensor(0.0638, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 114 Loss: tensor(0.0200, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 115 Loss: tensor(0.0808, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 116 Loss: tensor(0.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 117 Loss: tensor(0.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 118 Loss: tensor(0.0298, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 119 Loss: tensor(0.0255, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 120 Loss: tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 121 Loss: tensor(0.0300, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 122 Loss: tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 123 Loss: tensor(0.0389, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 124 Loss: tensor(0.0353, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 125 Loss: tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 126 Loss: tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 127 Loss: tensor(0.0301, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 128 Loss: tensor(0.0315, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 129 Loss: tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 130 Loss: tensor(0.1693, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 131 Loss: tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 132 Loss: tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 133 Loss: tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 134 Loss: tensor(0.1787, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 135 Loss: tensor(0.0334, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 136 Loss: tensor(0.1597, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 137 Loss: tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 138 Loss: tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 139 Loss: tensor(0.0363, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 140 Loss: tensor(0.0405, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 141 Loss: tensor(0.4120, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 142 Loss: tensor(0.0546, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 143 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 144 Loss: tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 145 Loss: tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 146 Loss: tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 147 Loss: tensor(0.1514, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 148 Loss: tensor(0.0301, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 149 Loss: tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 150 Loss: tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 151 Loss: tensor(0.0665, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 152 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 153 Loss: tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 154 Loss: tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 155 Loss: tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 156 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 157 Loss: tensor(0.0249, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 158 Loss: tensor(0.0330, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 159 Loss: tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 160 Loss: tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 161 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 162 Loss: tensor(0.3448, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 163 Loss: tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 164 Loss: tensor(0.0404, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 165 Loss: tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 166 Loss: tensor(0.0293, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 167 Loss: tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 168 Loss: tensor(0.0558, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 169 Loss: tensor(0.0351, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 170 Loss: tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 171 Loss: tensor(0.0346, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 172 Loss: tensor(0.0472, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 173 Loss: tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 174 Loss: tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 175 Loss: tensor(0.0439, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 176 Loss: tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 177 Loss: tensor(0.0348, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 178 Loss: tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 179 Loss: tensor(0.0556, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 180 Loss: tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 181 Loss: tensor(0.0300, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 182 Loss: tensor(0.0147, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 183 Loss: tensor(0.0248, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 184 Loss: tensor(0.0276, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 185 Loss: tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 186 Loss: tensor(0.0328, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 187 Loss: tensor(0.0288, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 188 Loss: tensor(0.0559, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 189 Loss: tensor(0.0246, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 190 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 191 Loss: tensor(0.0434, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 192 Loss: tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 193 Loss: tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 194 Loss: tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 195 Loss: tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 196 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 197 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 198 Loss: tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 199 Loss: tensor(0.0479, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 200 Loss: tensor(0.0289, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 201 Loss: tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 202 Loss: tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 203 Loss: tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 204 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 205 Loss: tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 206 Loss: tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 207 Loss: tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 208 Loss: tensor(0.0329, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 209 Loss: tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 210 Loss: tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 211 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 212 Loss: tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 213 Loss: tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 214 Loss: tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 215 Loss: tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 216 Loss: tensor(0.0312, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 217 Loss: tensor(0.0350, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 218 Loss: tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 219 Loss: tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 220 Loss: tensor(0.0278, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 221 Loss: tensor(0.0494, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 222 Loss: tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 223 Loss: tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 224 Loss: tensor(0.0175, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 225 Loss: tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 226 Loss: tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 227 Loss: tensor(0.0395, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 228 Loss: tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 229 Loss: tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 230 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 231 Loss: tensor(0.0527, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 232 Loss: tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 233 Loss: tensor(0.0284, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 234 Loss: tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 235 Loss: tensor(0.0353, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 236 Loss: tensor(0.0356, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 237 Loss: tensor(0.0338, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 238 Loss: tensor(0.0303, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 239 Loss: tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 240 Loss: tensor(0.0340, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 241 Loss: tensor(0.0335, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 242 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 243 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 244 Loss: tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 245 Loss: tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 246 Loss: tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 247 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 248 Loss: tensor(3.4323, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 249 Loss: tensor(0.0558, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 250 Loss: tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 251 Loss: tensor(0.0271, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 252 Loss: tensor(0.0142, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 253 Loss: tensor(0.0301, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 254 Loss: tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 255 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 256 Loss: tensor(0.0365, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 257 Loss: tensor(0.0343, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 258 Loss: tensor(0.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 259 Loss: tensor(0.0247, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 260 Loss: tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 261 Loss: tensor(0.0528, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 262 Loss: tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 263 Loss: tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 264 Loss: tensor(3.3211, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 265 Loss: tensor(0.1231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 266 Loss: tensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 267 Loss: tensor(0.0328, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 268 Loss: tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 269 Loss: tensor(0.0519, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 270 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 271 Loss: tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 272 Loss: tensor(0.0460, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 273 Loss: tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 274 Loss: tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 275 Loss: tensor(0.0604, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 276 Loss: tensor(0.0254, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 277 Loss: tensor(0.0291, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 278 Loss: tensor(0.0369, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 279 Loss: tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 280 Loss: tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 281 Loss: tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 282 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 283 Loss: tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 284 Loss: tensor(0.0259, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 285 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 286 Loss: tensor(0.0611, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 287 Loss: tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 288 Loss: tensor(0.0611, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 289 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 290 Loss: tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 291 Loss: tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 292 Loss: tensor(0.0280, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 293 Loss: tensor(0.0277, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 294 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 295 Loss: tensor(0.0291, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 296 Loss: tensor(0.0344, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 297 Loss: tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 298 Loss: tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 299 Loss: tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 300 Loss: tensor(0.2927, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 301 Loss: tensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 302 Loss: tensor(0.0227, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 303 Loss: tensor(0.0352, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 304 Loss: tensor(0.0285, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 305 Loss: tensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 306 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 307 Loss: tensor(0.0160, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 308 Loss: tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 309 Loss: tensor(0.0313, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 310 Loss: tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 311 Loss: tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 312 Loss: tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 313 Loss: tensor(0.0359, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 314 Loss: tensor(0.0382, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 315 Loss: tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 316 Loss: tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 317 Loss: tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 318 Loss: tensor(0.0382, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 319 Loss: tensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 320 Loss: tensor(0.0352, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 321 Loss: tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 322 Loss: tensor(0.1332, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 323 Loss: tensor(0.0161, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 324 Loss: tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 325 Loss: tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 326 Loss: tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 327 Loss: tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 328 Loss: tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 329 Loss: tensor(0.0374, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 330 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 331 Loss: tensor(0.0303, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 332 Loss: tensor(0.0147, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 333 Loss: tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 334 Loss: tensor(0.0331, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 335 Loss: tensor(0.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 336 Loss: tensor(0.0284, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 337 Loss: tensor(0.0322, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 338 Loss: tensor(0.0269, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 339 Loss: tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 340 Loss: tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 341 Loss: tensor(0.0280, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 342 Loss: tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 343 Loss: tensor(0.0271, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 344 Loss: tensor(0.0297, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 345 Loss: tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 346 Loss: tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 347 Loss: tensor(0.0285, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 348 Loss: tensor(0.0612, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 349 Loss: tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
