# %%
import os
os.environ['OMP_NUM_THREADS']='2'
os.environ['LD_LIBRARY_PATH']=''
os.environ['CUDA_LAUNCH_BLOCKING']='1'

# %%
# %cd /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR
# Out:
# /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR

# %%
from data_generation import *
from scipy.linalg import sqrtm
from downscaling import *
from utils import *
import random

# %%
# %cd Bicubic_Downsampling/
# Out:
# /home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR/Bicubic_Downsampling

# %% [markdown]
# ## Langevin & Training Downscale Network

# %% [markdown]
# ### Upscale By 4

# %%
N_low = 31
N_high = 121
scale = 4

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
A_high = create_A(N_high)
A_low = create_A(N_low)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for prior variance
prior_sigma = 0.002
ll_sigma = 0.002

# %%
G = np.eye(N_high**2) * prior_sigma**2
G_inverse = np.eye(N_high**2) * (1/prior_sigma**2)

# Turn matrices to tensors
G = torch.tensor(G).to(torch.float32).to(device)
G_inverse = torch.tensor(G_inverse).to(torch.float32).to(device)
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)

# Store sparse matrices as sparse tensor
A_high = A_high.to_sparse()
G = G.to_sparse()
G_inverse = G_inverse.to_sparse()
operator = torch.spmm(A_high.T,G_inverse).to(device)

# %%
dataset = DataFromH5File4("/home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR/data/31_121_low_forcing.h5")

trainset = random.sample(range(0, 128), 100)
testset = [i for i in range(0,128) if i not in trainset]

# %%
def sample_data():
    coefficient = random.sample(trainset,1)[0]
    forcing = dataset[coefficient][0]
    lr = dataset[coefficient][1]
    
    return forcing, lr


def sample_p_0():
    # Randomly sampling for initialisation of the Langevin dynamics
    # prior = torch.randn(*[batch_size,1,20,20]).to(device)
    
    # Set the u_low_mean to the initialisation of the Langevin dynamics
    posterior_initial = torch.randn([N_high,N_high]).to(torch.float32)
    posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
    
    return posterior_initial

    
def ula_posterior_preconditioner(z, b_high, x, G):
    """
    Langevin dynamics with preconditioner
    """
    z = z.clone().detach().requires_grad_(True)
    for i in range(K):
        # Grad log-likelihood
        downscaled = F.interpolate(z.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
        x_hat = downscaled + G(x.reshape(1,N_low,N_low)).reshape(N_low,N_low)
        log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
        grad_ll = torch.autograd.grad(log_likelihood, z)[0]

        # Grad prior
        difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
        # log_prior = - 0.5 * difference.T @ G_inverse @ difference
        # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
        grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
        
        # Random noise term
        W = torch.randn(*[N_high,N_high]).to(device)
        # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
        
        z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
        # chains_evolution.append(z.cpu().data.numpy())   
           
    return z.detach()

# %%
# Train with sampled data
epoch_num = 1000
lr = 0.001
gamma = 0.1
step_size = 50
minimum_loss = float('inf')
loss_track = []

K = 10000
s = 0.0004

G = ResidualLearning()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=step_size, gamma=gamma)

# Logger info
dir_name = f'models/model4/31_121/lr{lr}_gamma{gamma}_stepsize{step_size}_K{K}_llsigma_{ll_sigma}_psigma_{prior_sigma}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    b_high, low_res = sample_data()
    b_high = torch.tensor(b_high).to(torch.float32).to(device)
    low_res = torch.tensor(low_res).to(torch.float32).to(device)
    
    posterior_initial = sample_p_0()
    posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)

    optG.zero_grad()
    
    downscaled = F.interpolate(posterior_final.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
    out = G(low_res.reshape(1,N_low,N_low)) + downscaled
    loss = mse(out,low_res.reshape(1,N_low,N_low))
        
    loss.backward()
    optG.step()
    
    if loss < minimum_loss:
        save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
        minimum_loss = loss
            
    if epoch%100 == 0:
        save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
    
    save_model(dir_name, epoch, 'current_epoch', r_scheduleG, G, optG)
    
    loss_track.append(loss.cpu().data.numpy())
    np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
    
    print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()
# Out:
# 2024-06-04 14:13:43,679 : Training for 1000 epoches and learning rate is 0.001
# /tmp/ipykernel_27282/1398012651.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
# Epoch: 1 Loss: tensor(0.1343, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 2 Loss: tensor(0.0758, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 3 Loss: tensor(0.0484, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 4 Loss: tensor(0.0401, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 5 Loss: tensor(0.0904, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 6 Loss: tensor(0.0422, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 7 Loss: tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 8 Loss: tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 9 Loss: tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 10 Loss: tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 11 Loss: tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 12 Loss: tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 13 Loss: tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 14 Loss: tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 15 Loss: tensor(0.0296, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 16 Loss: tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 17 Loss: tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 18 Loss: tensor(0.0347, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 19 Loss: tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 20 Loss: tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 21 Loss: tensor(0.0644, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 22 Loss: tensor(0.0142, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 23 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 24 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 25 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 26 Loss: tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 27 Loss: tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 28 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 29 Loss: tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 30 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 31 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 32 Loss: tensor(0.0160, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 33 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 34 Loss: tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 35 Loss: tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 36 Loss: tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 37 Loss: tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 38 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 39 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 40 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 41 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 42 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 43 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 44 Loss: tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 45 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 46 Loss: tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 47 Loss: tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 48 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 49 Loss: tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 50 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 51 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 52 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 53 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 54 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 55 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 56 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 57 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 58 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 59 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 60 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 61 Loss: tensor(0.0780, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 62 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 63 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 64 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 65 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 66 Loss: tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 67 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 68 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 69 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 70 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 71 Loss: tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 72 Loss: tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 73 Loss: tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 74 Loss: tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 75 Loss: tensor(0.0708, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 76 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 77 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 78 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 79 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 80 Loss: tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 81 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 82 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 83 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 84 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 85 Loss: tensor(0.0141, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 86 Loss: tensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 87 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 88 Loss: tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 89 Loss: tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 90 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 91 Loss: tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 92 Loss: tensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 93 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 94 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 95 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 96 Loss: tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 97 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 98 Loss: tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 99 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 100 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 101 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 102 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 103 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 104 Loss: tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 105 Loss: tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 106 Loss: tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 107 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 108 Loss: tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 109 Loss: tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 110 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 111 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 112 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 113 Loss: tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 114 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 115 Loss: tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 116 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 117 Loss: tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 118 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 119 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 120 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 121 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 122 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 123 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 124 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 125 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 126 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 127 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 128 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 129 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 130 Loss: tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 131 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 132 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 133 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 134 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 135 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 136 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 137 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 138 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 139 Loss: tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 140 Loss: tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 141 Loss: tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 142 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 143 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 144 Loss: tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 145 Loss: tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 146 Loss: tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 147 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 148 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 149 Loss: tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 150 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 151 Loss: tensor(0.0679, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 152 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 153 Loss: tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 154 Loss: tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 155 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 156 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 157 Loss: tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 158 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 159 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 160 Loss: tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 161 Loss: tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 162 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 163 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 164 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 165 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 166 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 167 Loss: tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 168 Loss: tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 169 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 170 Loss: tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 171 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 172 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 173 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 174 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 175 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 176 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 177 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 178 Loss: tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 179 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 180 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 181 Loss: tensor(0.0141, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 182 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 183 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 184 Loss: tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 185 Loss: tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 186 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 187 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 188 Loss: tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 189 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 190 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 191 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 192 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 193 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 194 Loss: tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 195 Loss: tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 196 Loss: tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 197 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 198 Loss: tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 199 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 200 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 201 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 202 Loss: tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 203 Loss: tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 204 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 205 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 206 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 207 Loss: tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 208 Loss: tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 209 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 210 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 211 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 212 Loss: tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 213 Loss: tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 214 Loss: tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 215 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 216 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 217 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 218 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 219 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 220 Loss: tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 221 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 222 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 223 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 224 Loss: tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 225 Loss: tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 226 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 227 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 228 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 229 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 230 Loss: tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 231 Loss: tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 232 Loss: tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 233 Loss: tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 234 Loss: tensor(0.0686, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 235 Loss: tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 236 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 237 Loss: tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 238 Loss: tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 239 Loss: tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 240 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 241 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 242 Loss: tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 243 Loss: tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 244 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 245 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 246 Loss: tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 247 Loss: tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 248 Loss: tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 249 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 250 Loss: tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 251 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 252 Loss: tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 253 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 254 Loss: tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 255 Loss: tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 256 Loss: tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 257 Loss: tensor(0.0138, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 258 Loss: tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 31
#      28 low_res = torch.tensor(low_res).to(torch.float32).to(device)
#      30 posterior_initial = sample_p_0()
# ---> 31 posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)
#      33 optG.zero_grad()
#      35 downscaled = F.interpolate(posterior_final.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
#
# Cell In[11], line 30, in ula_posterior_preconditioner(z, b_high, x, G)
#      28 x_hat = downscaled + G(x.reshape(1,N_low,N_low)).reshape(N_low,N_low)
#      29 log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
# ---> 30 grad_ll = torch.autograd.grad(log_likelihood, z)[0]
#      32 # Grad prior
#      33 difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/autograd/__init__.py:300, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     298     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     299 else:
# --> 300     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     301         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     302         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:
